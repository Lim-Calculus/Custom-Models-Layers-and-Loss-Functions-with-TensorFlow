# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 232.5321 - y1_output_loss: 115.0113 - y2_output_loss: 115.9140 - y1_output_root_mean_squared_error: 10.7641 - y2_output_root_mean_squared_error: 10.8012 - val_loss: 60.4591 - val_y1_output_loss: 18.9316 - val_y2_output_loss: 39.6824 - val_y1_output_root_mean_squared_error: 4.4319 - val_y2_output_root_mean_squared_error: 6.3889
# Epoch 2/500
# 614/614 [==============================] - 0s 159us/sample - loss: 33.3616 - y1_output_loss: 12.1514 - y2_output_loss: 21.3642 - y1_output_root_mean_squared_error: 3.4941 - y2_output_root_mean_squared_error: 4.5992 - val_loss: 36.0086 - val_y1_output_loss: 10.6651 - val_y2_output_loss: 24.4428 - val_y1_output_root_mean_squared_error: 3.3203 - val_y2_output_root_mean_squared_error: 4.9984
# Epoch 3/500
# 614/614 [==============================] - 0s 179us/sample - loss: 26.6310 - y1_output_loss: 9.9747 - y2_output_loss: 16.7809 - y1_output_root_mean_squared_error: 3.1520 - y2_output_root_mean_squared_error: 4.0860 - val_loss: 50.8433 - val_y1_output_loss: 13.0302 - val_y2_output_loss: 36.6166 - val_y1_output_root_mean_squared_error: 3.6698 - val_y2_output_root_mean_squared_error: 6.1136
# Epoch 4/500
# 614/614 [==============================] - 0s 154us/sample - loss: 33.0329 - y1_output_loss: 11.1675 - y2_output_loss: 22.2729 - y1_output_root_mean_squared_error: 3.3056 - y2_output_root_mean_squared_error: 4.7017 - val_loss: 49.4472 - val_y1_output_loss: 17.4237 - val_y2_output_loss: 31.9123 - val_y1_output_root_mean_squared_error: 4.1523 - val_y2_output_root_mean_squared_error: 5.6750
# Epoch 5/500
# 614/614 [==============================] - 0s 148us/sample - loss: 24.7360 - y1_output_loss: 9.4908 - y2_output_loss: 15.0543 - y1_output_root_mean_squared_error: 3.0935 - y2_output_root_mean_squared_error: 3.8944 - val_loss: 18.3741 - val_y1_output_loss: 8.7680 - val_y2_output_loss: 9.0289 - val_y1_output_root_mean_squared_error: 3.0022 - val_y2_output_root_mean_squared_error: 3.0595
# Epoch 6/500
# 614/614 [==============================] - 0s 143us/sample - loss: 26.4497 - y1_output_loss: 9.6306 - y2_output_loss: 17.0436 - y1_output_root_mean_squared_error: 3.1025 - y2_output_root_mean_squared_error: 4.1018 - val_loss: 21.9182 - val_y1_output_loss: 10.5232 - val_y2_output_loss: 10.9686 - val_y1_output_root_mean_squared_error: 3.2648 - val_y2_output_root_mean_squared_error: 3.3554
# Epoch 7/500
# 614/614 [==============================] - 0s 166us/sample - loss: 24.3944 - y1_output_loss: 8.7548 - y2_output_loss: 15.7661 - y1_output_root_mean_squared_error: 2.9578 - y2_output_root_mean_squared_error: 3.9555 - val_loss: 25.7167 - val_y1_output_loss: 9.4655 - val_y2_output_loss: 15.4232 - val_y1_output_root_mean_squared_error: 3.1322 - val_y2_output_root_mean_squared_error: 3.9882
# Epoch 8/500
# 614/614 [==============================] - 0s 174us/sample - loss: 23.3122 - y1_output_loss: 8.5869 - y2_output_loss: 14.5670 - y1_output_root_mean_squared_error: 2.9404 - y2_output_root_mean_squared_error: 3.8297 - val_loss: 19.2469 - val_y1_output_loss: 9.1203 - val_y2_output_loss: 9.6888 - val_y1_output_root_mean_squared_error: 3.0406 - val_y2_output_root_mean_squared_error: 3.1625
# Epoch 9/500
# 614/614 [==============================] - 0s 190us/sample - loss: 21.7539 - y1_output_loss: 8.1254 - y2_output_loss: 13.5120 - y1_output_root_mean_squared_error: 2.8566 - y2_output_root_mean_squared_error: 3.6870 - val_loss: 17.8475 - val_y1_output_loss: 8.5816 - val_y2_output_loss: 8.8483 - val_y1_output_root_mean_squared_error: 2.9523 - val_y2_output_root_mean_squared_error: 3.0218
# Epoch 10/500
# 614/614 [==============================] - 0s 151us/sample - loss: 22.3266 - y1_output_loss: 8.1615 - y2_output_loss: 14.1811 - y1_output_root_mean_squared_error: 2.8653 - y2_output_root_mean_squared_error: 3.7572 - val_loss: 32.4436 - val_y1_output_loss: 9.6132 - val_y2_output_loss: 21.8762 - val_y1_output_root_mean_squared_error: 3.1556 - val_y2_output_root_mean_squared_error: 4.7419
# Epoch 11/500
# 614/614 [==============================] - 0s 146us/sample - loss: 23.6014 - y1_output_loss: 8.0933 - y2_output_loss: 15.3803 - y1_output_root_mean_squared_error: 2.8449 - y2_output_root_mean_squared_error: 3.9380 - val_loss: 21.2494 - val_y1_output_loss: 8.7468 - val_y2_output_loss: 12.2135 - val_y1_output_root_mean_squared_error: 2.9664 - val_y2_output_root_mean_squared_error: 3.5284
# Epoch 12/500
# 614/614 [==============================] - 0s 162us/sample - loss: 19.1262 - y1_output_loss: 7.4001 - y2_output_loss: 11.8469 - y1_output_root_mean_squared_error: 2.7037 - y2_output_root_mean_squared_error: 3.4375 - val_loss: 27.9509 - val_y1_output_loss: 9.2348 - val_y2_output_loss: 18.3096 - val_y1_output_root_mean_squared_error: 3.0478 - val_y2_output_root_mean_squared_error: 4.3199
# Epoch 13/500
# 614/614 [==============================] - 0s 152us/sample - loss: 20.1809 - y1_output_loss: 7.2807 - y2_output_loss: 12.8322 - y1_output_root_mean_squared_error: 2.7033 - y2_output_root_mean_squared_error: 3.5879 - val_loss: 28.6144 - val_y1_output_loss: 10.0527 - val_y2_output_loss: 17.6699 - val_y1_output_root_mean_squared_error: 3.2262 - val_y2_output_root_mean_squared_error: 4.2668
# Epoch 14/500
# 614/614 [==============================] - 0s 164us/sample - loss: 19.0922 - y1_output_loss: 6.9118 - y2_output_loss: 12.4108 - y1_output_root_mean_squared_error: 2.6197 - y2_output_root_mean_squared_error: 3.4970 - val_loss: 36.0080 - val_y1_output_loss: 11.0825 - val_y2_output_loss: 24.5328 - val_y1_output_root_mean_squared_error: 3.3314 - val_y2_output_root_mean_squared_error: 4.9910
# Epoch 15/500
# 614/614 [==============================] - 0s 161us/sample - loss: 18.4045 - y1_output_loss: 6.9548 - y2_output_loss: 11.4823 - y1_output_root_mean_squared_error: 2.6253 - y2_output_root_mean_squared_error: 3.3930 - val_loss: 14.1539 - val_y1_output_loss: 6.7899 - val_y2_output_loss: 6.9695 - val_y1_output_root_mean_squared_error: 2.6319 - val_y2_output_root_mean_squared_error: 2.6883
# Epoch 16/500
# 614/614 [==============================] - 0s 144us/sample - loss: 16.4249 - y1_output_loss: 6.1518 - y2_output_loss: 10.1969 - y1_output_root_mean_squared_error: 2.4865 - y2_output_root_mean_squared_error: 3.2004 - val_loss: 15.4804 - val_y1_output_loss: 6.8977 - val_y2_output_loss: 8.0942 - val_y1_output_root_mean_squared_error: 2.6664 - val_y2_output_root_mean_squared_error: 2.8932
# Epoch 17/500
# 614/614 [==============================] - 0s 142us/sample - loss: 15.5769 - y1_output_loss: 6.2717 - y2_output_loss: 9.4371 - y1_output_root_mean_squared_error: 2.4979 - y2_output_root_mean_squared_error: 3.0557 - val_loss: 22.5379 - val_y1_output_loss: 7.7287 - val_y2_output_loss: 14.4228 - val_y1_output_root_mean_squared_error: 2.7951 - val_y2_output_root_mean_squared_error: 3.8374
# Epoch 18/500
# 614/614 [==============================] - 0s 156us/sample - loss: 15.7472 - y1_output_loss: 5.8837 - y2_output_loss: 10.0173 - y1_output_root_mean_squared_error: 2.4004 - y2_output_root_mean_squared_error: 3.1600 - val_loss: 17.0024 - val_y1_output_loss: 7.2847 - val_y2_output_loss: 9.4436 - val_y1_output_root_mean_squared_error: 2.7081 - val_y2_output_root_mean_squared_error: 3.1095
# Epoch 19/500
# 614/614 [==============================] - 0s 143us/sample - loss: 15.8694 - y1_output_loss: 5.7993 - y2_output_loss: 9.9524 - y1_output_root_mean_squared_error: 2.4181 - y2_output_root_mean_squared_error: 3.1658 - val_loss: 19.5219 - val_y1_output_loss: 6.9150 - val_y2_output_loss: 12.0129 - val_y1_output_root_mean_squared_error: 2.6756 - val_y2_output_root_mean_squared_error: 3.5161
# Epoch 20/500
# 614/614 [==============================] - 0s 171us/sample - loss: 16.8570 - y1_output_loss: 5.8401 - y2_output_loss: 10.9199 - y1_output_root_mean_squared_error: 2.4231 - y2_output_root_mean_squared_error: 3.3145 - val_loss: 13.4742 - val_y1_output_loss: 6.5464 - val_y2_output_loss: 6.6135 - val_y1_output_root_mean_squared_error: 2.5778 - val_y2_output_root_mean_squared_error: 2.6132
# Epoch 21/500
# 614/614 [==============================] - 0s 169us/sample - loss: 13.1838 - y1_output_loss: 5.1294 - y2_output_loss: 8.0409 - y1_output_root_mean_squared_error: 2.2705 - y2_output_root_mean_squared_error: 2.8335 - val_loss: 20.2372 - val_y1_output_loss: 8.8343 - val_y2_output_loss: 10.7250 - val_y1_output_root_mean_squared_error: 3.0277 - val_y2_output_root_mean_squared_error: 3.3272
# Epoch 22/500
# 614/614 [==============================] - 0s 145us/sample - loss: 13.5187 - y1_output_loss: 5.0670 - y2_output_loss: 8.6346 - y1_output_root_mean_squared_error: 2.2143 - y2_output_root_mean_squared_error: 2.9352 - val_loss: 27.2428 - val_y1_output_loss: 8.5461 - val_y2_output_loss: 18.0292 - val_y1_output_root_mean_squared_error: 2.9532 - val_y2_output_root_mean_squared_error: 4.3037
# Epoch 23/500
# 614/614 [==============================] - 0s 152us/sample - loss: 15.8633 - y1_output_loss: 5.5424 - y2_output_loss: 10.1713 - y1_output_root_mean_squared_error: 2.3652 - y2_output_root_mean_squared_error: 3.2046 - val_loss: 22.1588 - val_y1_output_loss: 9.1700 - val_y2_output_loss: 12.3336 - val_y1_output_root_mean_squared_error: 3.0836 - val_y2_output_root_mean_squared_error: 3.5567
# Epoch 24/500
# 614/614 [==============================] - 0s 159us/sample - loss: 11.9904 - y1_output_loss: 4.4386 - y2_output_loss: 7.6864 - y1_output_root_mean_squared_error: 2.1052 - y2_output_root_mean_squared_error: 2.7492 - val_loss: 34.4616 - val_y1_output_loss: 8.7585 - val_y2_output_loss: 24.9135 - val_y1_output_root_mean_squared_error: 3.0118 - val_y2_output_root_mean_squared_error: 5.0389
# Epoch 25/500
# 614/614 [==============================] - 0s 171us/sample - loss: 11.7024 - y1_output_loss: 4.5380 - y2_output_loss: 7.1573 - y1_output_root_mean_squared_error: 2.1293 - y2_output_root_mean_squared_error: 2.6774 - val_loss: 13.0615 - val_y1_output_loss: 5.9094 - val_y2_output_loss: 6.7974 - val_y1_output_root_mean_squared_error: 2.4545 - val_y2_output_root_mean_squared_error: 2.6528
# Epoch 26/500
# 614/614 [==============================] - 0s 170us/sample - loss: 11.3370 - y1_output_loss: 4.2173 - y2_output_loss: 7.1363 - y1_output_root_mean_squared_error: 2.0572 - y2_output_root_mean_squared_error: 2.6655 - val_loss: 14.1058 - val_y1_output_loss: 5.0027 - val_y2_output_loss: 8.9059 - val_y1_output_root_mean_squared_error: 2.2429 - val_y2_output_root_mean_squared_error: 3.0125
# Epoch 27/500
# 614/614 [==============================] - 0s 143us/sample - loss: 11.1260 - y1_output_loss: 4.0316 - y2_output_loss: 7.0622 - y1_output_root_mean_squared_error: 2.0050 - y2_output_root_mean_squared_error: 2.6657 - val_loss: 10.4356 - val_y1_output_loss: 4.3364 - val_y2_output_loss: 5.8334 - val_y1_output_root_mean_squared_error: 2.1011 - val_y2_output_root_mean_squared_error: 2.4537
# Epoch 28/500
# 614/614 [==============================] - 0s 147us/sample - loss: 9.6817 - y1_output_loss: 3.7388 - y2_output_loss: 5.8763 - y1_output_root_mean_squared_error: 1.9410 - y2_output_root_mean_squared_error: 2.4319 - val_loss: 10.6380 - val_y1_output_loss: 4.5053 - val_y2_output_loss: 5.7767 - val_y1_output_root_mean_squared_error: 2.1594 - val_y2_output_root_mean_squared_error: 2.4444
# Epoch 29/500
# 614/614 [==============================] - 0s 168us/sample - loss: 9.8910 - y1_output_loss: 3.4552 - y2_output_loss: 6.3688 - y1_output_root_mean_squared_error: 1.8630 - y2_output_root_mean_squared_error: 2.5338 - val_loss: 8.9034 - val_y1_output_loss: 4.4731 - val_y2_output_loss: 4.1399 - val_y1_output_root_mean_squared_error: 2.1482 - val_y2_output_root_mean_squared_error: 2.0709
# Epoch 30/500
# 614/614 [==============================] - 0s 148us/sample - loss: 10.0082 - y1_output_loss: 3.3459 - y2_output_loss: 6.7380 - y1_output_root_mean_squared_error: 1.8090 - y2_output_root_mean_squared_error: 2.5953 - val_loss: 16.0213 - val_y1_output_loss: 6.2458 - val_y2_output_loss: 9.5938 - val_y1_output_root_mean_squared_error: 2.4964 - val_y2_output_root_mean_squared_error: 3.1288
# Epoch 31/500
# 614/614 [==============================] - 0s 165us/sample - loss: 8.5635 - y1_output_loss: 3.2539 - y2_output_loss: 5.2731 - y1_output_root_mean_squared_error: 1.8103 - y2_output_root_mean_squared_error: 2.2992 - val_loss: 10.5147 - val_y1_output_loss: 4.1977 - val_y2_output_loss: 6.2364 - val_y1_output_root_mean_squared_error: 2.0422 - val_y2_output_root_mean_squared_error: 2.5187
# Epoch 32/500
# 614/614 [==============================] - 0s 160us/sample - loss: 10.9638 - y1_output_loss: 3.6447 - y2_output_loss: 7.2214 - y1_output_root_mean_squared_error: 1.9182 - y2_output_root_mean_squared_error: 2.6990 - val_loss: 7.1911 - val_y1_output_loss: 3.2296 - val_y2_output_loss: 3.8010 - val_y1_output_root_mean_squared_error: 1.8067 - val_y2_output_root_mean_squared_error: 1.9817
# Epoch 33/500
# 614/614 [==============================] - 0s 147us/sample - loss: 9.3934 - y1_output_loss: 3.2870 - y2_output_loss: 6.0182 - y1_output_root_mean_squared_error: 1.8216 - y2_output_root_mean_squared_error: 2.4648 - val_loss: 8.2706 - val_y1_output_loss: 3.4602 - val_y2_output_loss: 4.5347 - val_y1_output_root_mean_squared_error: 1.8890 - val_y2_output_root_mean_squared_error: 2.1685
# Epoch 34/500
# 614/614 [==============================] - 0s 146us/sample - loss: 8.8795 - y1_output_loss: 3.1369 - y2_output_loss: 5.6609 - y1_output_root_mean_squared_error: 1.7792 - y2_output_root_mean_squared_error: 2.3904 - val_loss: 7.0204 - val_y1_output_loss: 3.1685 - val_y2_output_loss: 3.6741 - val_y1_output_root_mean_squared_error: 1.7932 - val_y2_output_root_mean_squared_error: 1.9506
# Epoch 35/500
# 614/614 [==============================] - 0s 163us/sample - loss: 9.2061 - y1_output_loss: 3.2601 - y2_output_loss: 5.9041 - y1_output_root_mean_squared_error: 1.8132 - y2_output_root_mean_squared_error: 2.4328 - val_loss: 8.8495 - val_y1_output_loss: 3.3539 - val_y2_output_loss: 5.2161 - val_y1_output_root_mean_squared_error: 1.8544 - val_y2_output_root_mean_squared_error: 2.3261
# Epoch 36/500
# 614/614 [==============================] - 0s 161us/sample - loss: 11.3350 - y1_output_loss: 3.5006 - y2_output_loss: 7.7963 - y1_output_root_mean_squared_error: 1.8726 - y2_output_root_mean_squared_error: 2.7979 - val_loss: 21.8120 - val_y1_output_loss: 8.3701 - val_y2_output_loss: 12.6866 - val_y1_output_root_mean_squared_error: 2.9478 - val_y2_output_root_mean_squared_error: 3.6225
# Epoch 37/500
# 614/614 [==============================] - 0s 163us/sample - loss: 10.8014 - y1_output_loss: 3.5452 - y2_output_loss: 7.2937 - y1_output_root_mean_squared_error: 1.8793 - y2_output_root_mean_squared_error: 2.6962 - val_loss: 10.4294 - val_y1_output_loss: 3.8928 - val_y2_output_loss: 6.3992 - val_y1_output_root_mean_squared_error: 1.9771 - val_y2_output_root_mean_squared_error: 2.5535
# Epoch 38/500
# 614/614 [==============================] - 0s 149us/sample - loss: 10.9939 - y1_output_loss: 3.8072 - y2_output_loss: 7.2933 - y1_output_root_mean_squared_error: 1.9441 - y2_output_root_mean_squared_error: 2.6860 - val_loss: 21.2061 - val_y1_output_loss: 4.1987 - val_y2_output_loss: 16.7584 - val_y1_output_root_mean_squared_error: 2.0489 - val_y2_output_root_mean_squared_error: 4.1241
# Epoch 39/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.2408 - y1_output_loss: 2.3608 - y2_output_loss: 4.8243 - y1_output_root_mean_squared_error: 1.5422 - y2_output_root_mean_squared_error: 2.2051 - val_loss: 7.6237 - val_y1_output_loss: 3.3394 - val_y2_output_loss: 4.1812 - val_y1_output_root_mean_squared_error: 1.8256 - val_y2_output_root_mean_squared_error: 2.0715
# Epoch 40/500
# 614/614 [==============================] - 0s 153us/sample - loss: 7.5576 - y1_output_loss: 2.6097 - y2_output_loss: 4.9106 - y1_output_root_mean_squared_error: 1.6150 - y2_output_root_mean_squared_error: 2.2247 - val_loss: 7.9957 - val_y1_output_loss: 3.7754 - val_y2_output_loss: 3.9576 - val_y1_output_root_mean_squared_error: 1.9740 - val_y2_output_root_mean_squared_error: 2.0246
# Epoch 41/500
# 614/614 [==============================] - 0s 156us/sample - loss: 7.9959 - y1_output_loss: 2.6310 - y2_output_loss: 5.4150 - y1_output_root_mean_squared_error: 1.6256 - y2_output_root_mean_squared_error: 2.3137 - val_loss: 31.7210 - val_y1_output_loss: 6.5734 - val_y2_output_loss: 24.3454 - val_y1_output_root_mean_squared_error: 2.6124 - val_y2_output_root_mean_squared_error: 4.9896
# Epoch 42/500
# 614/614 [==============================] - 0s 162us/sample - loss: 7.6415 - y1_output_loss: 2.5812 - y2_output_loss: 4.9963 - y1_output_root_mean_squared_error: 1.6136 - y2_output_root_mean_squared_error: 2.2445 - val_loss: 6.6172 - val_y1_output_loss: 2.5860 - val_y2_output_loss: 3.8740 - val_y1_output_root_mean_squared_error: 1.6230 - val_y2_output_root_mean_squared_error: 1.9958
# Epoch 43/500
# 614/614 [==============================] - 0s 158us/sample - loss: 9.5873 - y1_output_loss: 3.2833 - y2_output_loss: 6.3204 - y1_output_root_mean_squared_error: 1.7994 - y2_output_root_mean_squared_error: 2.5198 - val_loss: 6.4136 - val_y1_output_loss: 2.8120 - val_y2_output_loss: 3.4030 - val_y1_output_root_mean_squared_error: 1.6982 - val_y2_output_root_mean_squared_error: 1.8788
# Epoch 44/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.4272 - y1_output_loss: 2.2591 - y2_output_loss: 4.2786 - y1_output_root_mean_squared_error: 1.4950 - y2_output_root_mean_squared_error: 2.0475 - val_loss: 7.1305 - val_y1_output_loss: 2.9495 - val_y2_output_loss: 4.0349 - val_y1_output_root_mean_squared_error: 1.7172 - val_y2_output_root_mean_squared_error: 2.0450
# Epoch 45/500
# 614/614 [==============================] - 0s 152us/sample - loss: 9.6418 - y1_output_loss: 2.9141 - y2_output_loss: 6.7379 - y1_output_root_mean_squared_error: 1.6916 - y2_output_root_mean_squared_error: 2.6039 - val_loss: 10.6809 - val_y1_output_loss: 5.0077 - val_y2_output_loss: 5.2953 - val_y1_output_root_mean_squared_error: 2.2798 - val_y2_output_root_mean_squared_error: 2.3417
# Epoch 46/500
# 614/614 [==============================] - 0s 164us/sample - loss: 7.5512 - y1_output_loss: 2.4624 - y2_output_loss: 5.0226 - y1_output_root_mean_squared_error: 1.5764 - y2_output_root_mean_squared_error: 2.2508 - val_loss: 5.5233 - val_y1_output_loss: 2.3574 - val_y2_output_loss: 3.0656 - val_y1_output_root_mean_squared_error: 1.5366 - val_y2_output_root_mean_squared_error: 1.7783
# Epoch 47/500
# 614/614 [==============================] - 0s 149us/sample - loss: 7.6362 - y1_output_loss: 2.4348 - y2_output_loss: 5.2441 - y1_output_root_mean_squared_error: 1.5468 - y2_output_root_mean_squared_error: 2.2899 - val_loss: 15.4866 - val_y1_output_loss: 4.7884 - val_y2_output_loss: 10.1939 - val_y1_output_root_mean_squared_error: 2.2278 - val_y2_output_root_mean_squared_error: 3.2440
# Epoch 48/500
# 614/614 [==============================] - 0s 159us/sample - loss: 8.6910 - y1_output_loss: 2.7094 - y2_output_loss: 5.9304 - y1_output_root_mean_squared_error: 1.6470 - y2_output_root_mean_squared_error: 2.4451 - val_loss: 7.8042 - val_y1_output_loss: 3.5961 - val_y2_output_loss: 3.9280 - val_y1_output_root_mean_squared_error: 1.9311 - val_y2_output_root_mean_squared_error: 2.0187
# Epoch 49/500
# 614/614 [==============================] - 0s 165us/sample - loss: 7.4629 - y1_output_loss: 2.3406 - y2_output_loss: 5.1502 - y1_output_root_mean_squared_error: 1.5264 - y2_output_root_mean_squared_error: 2.2656 - val_loss: 8.6313 - val_y1_output_loss: 3.2380 - val_y2_output_loss: 5.3817 - val_y1_output_root_mean_squared_error: 1.7825 - val_y2_output_root_mean_squared_error: 2.3354
# Epoch 50/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.4408 - y1_output_loss: 2.3522 - y2_output_loss: 5.0250 - y1_output_root_mean_squared_error: 1.5405 - y2_output_root_mean_squared_error: 2.2512 - val_loss: 12.1571 - val_y1_output_loss: 4.0929 - val_y2_output_loss: 7.6690 - val_y1_output_root_mean_squared_error: 2.0498 - val_y2_output_root_mean_squared_error: 2.8205
# Epoch 51/500
# 614/614 [==============================] - 0s 146us/sample - loss: 9.7227 - y1_output_loss: 3.0548 - y2_output_loss: 6.6059 - y1_output_root_mean_squared_error: 1.7542 - y2_output_root_mean_squared_error: 2.5779 - val_loss: 6.7069 - val_y1_output_loss: 2.5019 - val_y2_output_loss: 4.0147 - val_y1_output_root_mean_squared_error: 1.5947 - val_y2_output_root_mean_squared_error: 2.0405
# Epoch 52/500
# 614/614 [==============================] - 0s 185us/sample - loss: 6.2540 - y1_output_loss: 2.1408 - y2_output_loss: 4.1813 - y1_output_root_mean_squared_error: 1.4525 - y2_output_root_mean_squared_error: 2.0358 - val_loss: 9.4666 - val_y1_output_loss: 4.0294 - val_y2_output_loss: 5.1668 - val_y1_output_root_mean_squared_error: 2.0296 - val_y2_output_root_mean_squared_error: 2.3125
# Epoch 53/500
# 614/614 [==============================] - 0s 170us/sample - loss: 15.6167 - y1_output_loss: 4.9910 - y2_output_loss: 10.5593 - y1_output_root_mean_squared_error: 2.2433 - y2_output_root_mean_squared_error: 3.2534 - val_loss: 8.4116 - val_y1_output_loss: 4.1533 - val_y2_output_loss: 4.0058 - val_y1_output_root_mean_squared_error: 2.0688 - val_y2_output_root_mean_squared_error: 2.0326
# Epoch 54/500
# 614/614 [==============================] - 0s 179us/sample - loss: 6.6280 - y1_output_loss: 2.2480 - y2_output_loss: 4.3970 - y1_output_root_mean_squared_error: 1.4958 - y2_output_root_mean_squared_error: 2.0954 - val_loss: 10.9863 - val_y1_output_loss: 2.8690 - val_y2_output_loss: 7.7745 - val_y1_output_root_mean_squared_error: 1.7198 - val_y2_output_root_mean_squared_error: 2.8334
# Epoch 55/500
# 614/614 [==============================] - 0s 159us/sample - loss: 6.3523 - y1_output_loss: 2.0921 - y2_output_loss: 4.2453 - y1_output_root_mean_squared_error: 1.4518 - y2_output_root_mean_squared_error: 2.0602 - val_loss: 8.6232 - val_y1_output_loss: 3.1934 - val_y2_output_loss: 5.1385 - val_y1_output_root_mean_squared_error: 1.8189 - val_y2_output_root_mean_squared_error: 2.3054
# Epoch 56/500
# 614/614 [==============================] - 0s 149us/sample - loss: 5.8214 - y1_output_loss: 1.8595 - y2_output_loss: 4.3199 - y1_output_root_mean_squared_error: 1.3500 - y2_output_root_mean_squared_error: 1.9997 - val_loss: 30.4026 - val_y1_output_loss: 7.6895 - val_y2_output_loss: 21.9303 - val_y1_output_root_mean_squared_error: 2.8244 - val_y2_output_root_mean_squared_error: 4.7355
# Epoch 57/500
# 614/614 [==============================] - 0s 162us/sample - loss: 8.0113 - y1_output_loss: 2.3979 - y2_output_loss: 5.6259 - y1_output_root_mean_squared_error: 1.5475 - y2_output_root_mean_squared_error: 2.3699 - val_loss: 4.9296 - val_y1_output_loss: 2.1649 - val_y2_output_loss: 2.7151 - val_y1_output_root_mean_squared_error: 1.4595 - val_y2_output_root_mean_squared_error: 1.6731
# Epoch 58/500
# 614/614 [==============================] - 0s 150us/sample - loss: 7.0200 - y1_output_loss: 2.0086 - y2_output_loss: 5.0766 - y1_output_root_mean_squared_error: 1.4160 - y2_output_root_mean_squared_error: 2.2394 - val_loss: 8.0867 - val_y1_output_loss: 2.8865 - val_y2_output_loss: 4.9326 - val_y1_output_root_mean_squared_error: 1.7276 - val_y2_output_root_mean_squared_error: 2.2588
# Epoch 59/500
# 614/614 [==============================] - 0s 174us/sample - loss: 10.2291 - y1_output_loss: 2.9687 - y2_output_loss: 7.2414 - y1_output_root_mean_squared_error: 1.7216 - y2_output_root_mean_squared_error: 2.6954 - val_loss: 12.0064 - val_y1_output_loss: 3.6686 - val_y2_output_loss: 8.2657 - val_y1_output_root_mean_squared_error: 1.9115 - val_y2_output_root_mean_squared_error: 2.8901
# Epoch 60/500
# 614/614 [==============================] - 0s 163us/sample - loss: 6.3603 - y1_output_loss: 2.0126 - y2_output_loss: 4.3558 - y1_output_root_mean_squared_error: 1.4219 - y2_output_root_mean_squared_error: 2.0829 - val_loss: 7.2969 - val_y1_output_loss: 2.4428 - val_y2_output_loss: 4.6164 - val_y1_output_root_mean_squared_error: 1.5861 - val_y2_output_root_mean_squared_error: 2.1866
# Epoch 61/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.6970 - y1_output_loss: 1.8210 - y2_output_loss: 3.8276 - y1_output_root_mean_squared_error: 1.3558 - y2_output_root_mean_squared_error: 1.9644 - val_loss: 4.2996 - val_y1_output_loss: 1.6797 - val_y2_output_loss: 2.5079 - val_y1_output_root_mean_squared_error: 1.3047 - val_y2_output_root_mean_squared_error: 1.6117
# Epoch 62/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.2478 - y1_output_loss: 1.6058 - y2_output_loss: 3.6423 - y1_output_root_mean_squared_error: 1.2647 - y2_output_root_mean_squared_error: 1.9100 - val_loss: 8.3234 - val_y1_output_loss: 2.1412 - val_y2_output_loss: 5.9332 - val_y1_output_root_mean_squared_error: 1.4833 - val_y2_output_root_mean_squared_error: 2.4745
# Epoch 63/500
# 614/614 [==============================] - 0s 162us/sample - loss: 5.6111 - y1_output_loss: 1.7185 - y2_output_loss: 3.8579 - y1_output_root_mean_squared_error: 1.3106 - y2_output_root_mean_squared_error: 1.9732 - val_loss: 4.2821 - val_y1_output_loss: 1.8281 - val_y2_output_loss: 2.4126 - val_y1_output_root_mean_squared_error: 1.3481 - val_y2_output_root_mean_squared_error: 1.5699
# Epoch 64/500
# 614/614 [==============================] - 0s 154us/sample - loss: 4.5590 - y1_output_loss: 1.5489 - y2_output_loss: 3.0022 - y1_output_root_mean_squared_error: 1.2471 - y2_output_root_mean_squared_error: 1.7331 - val_loss: 8.2544 - val_y1_output_loss: 1.6659 - val_y2_output_loss: 6.5432 - val_y1_output_root_mean_squared_error: 1.2789 - val_y2_output_root_mean_squared_error: 2.5727
# Epoch 65/500
# 614/614 [==============================] - 0s 167us/sample - loss: 5.4963 - y1_output_loss: 1.5828 - y2_output_loss: 3.9057 - y1_output_root_mean_squared_error: 1.2532 - y2_output_root_mean_squared_error: 1.9814 - val_loss: 5.1842 - val_y1_output_loss: 1.6966 - val_y2_output_loss: 3.4664 - val_y1_output_root_mean_squared_error: 1.2967 - val_y2_output_root_mean_squared_error: 1.8716
# Epoch 66/500
# 614/614 [==============================] - 0s 154us/sample - loss: 5.3450 - y1_output_loss: 1.5842 - y2_output_loss: 3.8029 - y1_output_root_mean_squared_error: 1.2608 - y2_output_root_mean_squared_error: 1.9379 - val_loss: 24.7139 - val_y1_output_loss: 5.0320 - val_y2_output_loss: 18.9933 - val_y1_output_root_mean_squared_error: 2.2863 - val_y2_output_root_mean_squared_error: 4.4144
# Epoch 67/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.5195 - y1_output_loss: 1.6599 - y2_output_loss: 3.8527 - y1_output_root_mean_squared_error: 1.2857 - y2_output_root_mean_squared_error: 1.9663 - val_loss: 10.2652 - val_y1_output_loss: 4.0299 - val_y2_output_loss: 6.2985 - val_y1_output_root_mean_squared_error: 1.9792 - val_y2_output_root_mean_squared_error: 2.5195
# Epoch 68/500
# 614/614 [==============================] - 0s 149us/sample - loss: 5.2917 - y1_output_loss: 1.5757 - y2_output_loss: 3.8359 - y1_output_root_mean_squared_error: 1.2534 - y2_output_root_mean_squared_error: 1.9289 - val_loss: 17.4916 - val_y1_output_loss: 4.0953 - val_y2_output_loss: 12.8681 - val_y1_output_root_mean_squared_error: 2.0619 - val_y2_output_root_mean_squared_error: 3.6387
# Epoch 69/500
# 614/614 [==============================] - 0s 157us/sample - loss: 4.6707 - y1_output_loss: 1.4495 - y2_output_loss: 3.1945 - y1_output_root_mean_squared_error: 1.2058 - y2_output_root_mean_squared_error: 1.7936 - val_loss: 3.5426 - val_y1_output_loss: 1.4243 - val_y2_output_loss: 2.0621 - val_y1_output_root_mean_squared_error: 1.1897 - val_y2_output_root_mean_squared_error: 1.4585
# Epoch 70/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.8199 - y1_output_loss: 1.2312 - y2_output_loss: 2.5934 - y1_output_root_mean_squared_error: 1.1034 - y2_output_root_mean_squared_error: 1.6132 - val_loss: 3.6845 - val_y1_output_loss: 1.4216 - val_y2_output_loss: 2.2293 - val_y1_output_root_mean_squared_error: 1.1847 - val_y2_output_root_mean_squared_error: 1.5103
# Epoch 71/500
# 614/614 [==============================] - 0s 167us/sample - loss: 4.0732 - y1_output_loss: 1.1149 - y2_output_loss: 2.9554 - y1_output_root_mean_squared_error: 1.0544 - y2_output_root_mean_squared_error: 1.7209 - val_loss: 6.0038 - val_y1_output_loss: 2.4085 - val_y2_output_loss: 3.3878 - val_y1_output_root_mean_squared_error: 1.5800 - val_y2_output_root_mean_squared_error: 1.8728
# Epoch 72/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.8886 - y1_output_loss: 1.3933 - y2_output_loss: 3.4737 - y1_output_root_mean_squared_error: 1.1847 - y2_output_root_mean_squared_error: 1.8668 - val_loss: 5.5526 - val_y1_output_loss: 1.8476 - val_y2_output_loss: 3.5320 - val_y1_output_root_mean_squared_error: 1.3789 - val_y2_output_root_mean_squared_error: 1.9109
# Epoch 73/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.0725 - y1_output_loss: 1.2296 - y2_output_loss: 2.8349 - y1_output_root_mean_squared_error: 1.1110 - y2_output_root_mean_squared_error: 1.6847 - val_loss: 6.6381 - val_y1_output_loss: 2.6605 - val_y2_output_loss: 3.7926 - val_y1_output_root_mean_squared_error: 1.6480 - val_y2_output_root_mean_squared_error: 1.9805
# Epoch 74/500
# 614/614 [==============================] - 0s 152us/sample - loss: 4.3120 - y1_output_loss: 1.2946 - y2_output_loss: 3.0350 - y1_output_root_mean_squared_error: 1.1326 - y2_output_root_mean_squared_error: 1.7405 - val_loss: 3.5624 - val_y1_output_loss: 1.1652 - val_y2_output_loss: 2.2895 - val_y1_output_root_mean_squared_error: 1.0945 - val_y2_output_root_mean_squared_error: 1.5376
# Epoch 75/500
# 614/614 [==============================] - 0s 152us/sample - loss: 4.0486 - y1_output_loss: 1.1874 - y2_output_loss: 2.8442 - y1_output_root_mean_squared_error: 1.0914 - y2_output_root_mean_squared_error: 1.6904 - val_loss: 4.6950 - val_y1_output_loss: 1.4515 - val_y2_output_loss: 3.0972 - val_y1_output_root_mean_squared_error: 1.2231 - val_y2_output_root_mean_squared_error: 1.7886
# Epoch 76/500
# 614/614 [==============================] - 0s 160us/sample - loss: 3.6716 - y1_output_loss: 1.0694 - y2_output_loss: 2.5732 - y1_output_root_mean_squared_error: 1.0384 - y2_output_root_mean_squared_error: 1.6104 - val_loss: 3.3271 - val_y1_output_loss: 1.0716 - val_y2_output_loss: 2.1470 - val_y1_output_root_mean_squared_error: 1.0493 - val_y2_output_root_mean_squared_error: 1.4920
# Epoch 77/500
# 614/614 [==============================] - 0s 170us/sample - loss: 3.9998 - y1_output_loss: 1.1448 - y2_output_loss: 2.8377 - y1_output_root_mean_squared_error: 1.0677 - y2_output_root_mean_squared_error: 1.6911 - val_loss: 2.9541 - val_y1_output_loss: 1.1401 - val_y2_output_loss: 1.7291 - val_y1_output_root_mean_squared_error: 1.0785 - val_y2_output_root_mean_squared_error: 1.3383
# Epoch 78/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.0835 - y1_output_loss: 0.8720 - y2_output_loss: 2.2114 - y1_output_root_mean_squared_error: 0.9359 - y2_output_root_mean_squared_error: 1.4858 - val_loss: 2.9192 - val_y1_output_loss: 0.9440 - val_y2_output_loss: 1.9231 - val_y1_output_root_mean_squared_error: 0.9752 - val_y2_output_root_mean_squared_error: 1.4029
# Epoch 79/500
# 614/614 [==============================] - 0s 150us/sample - loss: 4.3426 - y1_output_loss: 1.0390 - y2_output_loss: 3.2915 - y1_output_root_mean_squared_error: 1.0243 - y2_output_root_mean_squared_error: 1.8148 - val_loss: 3.5973 - val_y1_output_loss: 1.1466 - val_y2_output_loss: 2.3526 - val_y1_output_root_mean_squared_error: 1.0775 - val_y2_output_root_mean_squared_error: 1.5609
# Epoch 80/500
# 614/614 [==============================] - 0s 151us/sample - loss: 5.2468 - y1_output_loss: 1.3678 - y2_output_loss: 3.8804 - y1_output_root_mean_squared_error: 1.1657 - y2_output_root_mean_squared_error: 1.9718 - val_loss: 4.9400 - val_y1_output_loss: 1.9819 - val_y2_output_loss: 2.9594 - val_y1_output_root_mean_squared_error: 1.3905 - val_y2_output_root_mean_squared_error: 1.7339
# Epoch 81/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.3553 - y1_output_loss: 0.9838 - y2_output_loss: 2.3518 - y1_output_root_mean_squared_error: 0.9953 - y2_output_root_mean_squared_error: 1.5378 - val_loss: 3.2888 - val_y1_output_loss: 0.9839 - val_y2_output_loss: 2.2421 - val_y1_output_root_mean_squared_error: 0.9970 - val_y2_output_root_mean_squared_error: 1.5149
# Epoch 82/500
# 614/614 [==============================] - 0s 156us/sample - loss: 4.6675 - y1_output_loss: 1.2172 - y2_output_loss: 3.4188 - y1_output_root_mean_squared_error: 1.1082 - y2_output_root_mean_squared_error: 1.8546 - val_loss: 2.4398 - val_y1_output_loss: 0.8453 - val_y2_output_loss: 1.5329 - val_y1_output_root_mean_squared_error: 0.9256 - val_y2_output_root_mean_squared_error: 1.2582
# Epoch 83/500
# 614/614 [==============================] - 0s 160us/sample - loss: 2.7206 - y1_output_loss: 0.8030 - y2_output_loss: 1.9268 - y1_output_root_mean_squared_error: 0.9001 - y2_output_root_mean_squared_error: 1.3822 - val_loss: 2.8966 - val_y1_output_loss: 0.8217 - val_y2_output_loss: 2.0324 - val_y1_output_root_mean_squared_error: 0.9035 - val_y2_output_root_mean_squared_error: 1.4423
# Epoch 84/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.3182 - y1_output_loss: 0.9388 - y2_output_loss: 2.3617 - y1_output_root_mean_squared_error: 0.9686 - y2_output_root_mean_squared_error: 1.5427 - val_loss: 2.9676 - val_y1_output_loss: 0.9427 - val_y2_output_loss: 1.9799 - val_y1_output_root_mean_squared_error: 0.9675 - val_y2_output_root_mean_squared_error: 1.4253
# Epoch 85/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.1579 - y1_output_loss: 1.0230 - y2_output_loss: 3.1380 - y1_output_root_mean_squared_error: 1.0078 - y2_output_root_mean_squared_error: 1.7726 - val_loss: 2.5762 - val_y1_output_loss: 0.9920 - val_y2_output_loss: 1.5302 - val_y1_output_root_mean_squared_error: 0.9959 - val_y2_output_root_mean_squared_error: 1.2587
# Epoch 86/500
# 614/614 [==============================] - 0s 154us/sample - loss: 4.7439 - y1_output_loss: 1.2520 - y2_output_loss: 3.4904 - y1_output_root_mean_squared_error: 1.1222 - y2_output_root_mean_squared_error: 1.8667 - val_loss: 7.0718 - val_y1_output_loss: 1.1282 - val_y2_output_loss: 5.8843 - val_y1_output_root_mean_squared_error: 1.0564 - val_y2_output_root_mean_squared_error: 2.4405
# Epoch 87/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.0963 - y1_output_loss: 0.7726 - y2_output_loss: 2.3052 - y1_output_root_mean_squared_error: 0.8792 - y2_output_root_mean_squared_error: 1.5242 - val_loss: 2.6424 - val_y1_output_loss: 0.9474 - val_y2_output_loss: 1.6046 - val_y1_output_root_mean_squared_error: 0.9890 - val_y2_output_root_mean_squared_error: 1.2901
# Epoch 88/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.7759 - y1_output_loss: 0.7246 - y2_output_loss: 2.0653 - y1_output_root_mean_squared_error: 0.8519 - y2_output_root_mean_squared_error: 1.4319 - val_loss: 3.3416 - val_y1_output_loss: 1.1544 - val_y2_output_loss: 2.0782 - val_y1_output_root_mean_squared_error: 1.0888 - val_y2_output_root_mean_squared_error: 1.4684
# Epoch 89/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.1396 - y1_output_loss: 0.9105 - y2_output_loss: 2.2240 - y1_output_root_mean_squared_error: 0.9530 - y2_output_root_mean_squared_error: 1.4938 - val_loss: 4.8213 - val_y1_output_loss: 1.5110 - val_y2_output_loss: 3.1755 - val_y1_output_root_mean_squared_error: 1.2443 - val_y2_output_root_mean_squared_error: 1.8092
# Epoch 90/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.2395 - y1_output_loss: 1.3323 - y2_output_loss: 3.8852 - y1_output_root_mean_squared_error: 1.1564 - y2_output_root_mean_squared_error: 1.9754 - val_loss: 2.3727 - val_y1_output_loss: 0.7795 - val_y2_output_loss: 1.5174 - val_y1_output_root_mean_squared_error: 0.8944 - val_y2_output_root_mean_squared_error: 1.2541
# Epoch 91/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.6485 - y1_output_loss: 1.0484 - y2_output_loss: 2.6201 - y1_output_root_mean_squared_error: 1.0271 - y2_output_root_mean_squared_error: 1.6105 - val_loss: 3.4722 - val_y1_output_loss: 1.0699 - val_y2_output_loss: 2.3039 - val_y1_output_root_mean_squared_error: 1.0432 - val_y2_output_root_mean_squared_error: 1.5440
# Epoch 92/500
# 614/614 [==============================] - 0s 158us/sample - loss: 3.8965 - y1_output_loss: 1.0194 - y2_output_loss: 2.8517 - y1_output_root_mean_squared_error: 1.0144 - y2_output_root_mean_squared_error: 1.6934 - val_loss: 3.7225 - val_y1_output_loss: 1.3916 - val_y2_output_loss: 2.2140 - val_y1_output_root_mean_squared_error: 1.1978 - val_y2_output_root_mean_squared_error: 1.5126
# Epoch 93/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.6562 - y1_output_loss: 0.7245 - y2_output_loss: 1.9672 - y1_output_root_mean_squared_error: 0.8545 - y2_output_root_mean_squared_error: 1.3878 - val_loss: 9.6686 - val_y1_output_loss: 1.7655 - val_y2_output_loss: 7.6631 - val_y1_output_root_mean_squared_error: 1.3521 - val_y2_output_root_mean_squared_error: 2.8001
# Epoch 94/500
# 614/614 [==============================] - 0s 162us/sample - loss: 3.7242 - y1_output_loss: 0.9714 - y2_output_loss: 2.7524 - y1_output_root_mean_squared_error: 0.9821 - y2_output_root_mean_squared_error: 1.6612 - val_loss: 3.4524 - val_y1_output_loss: 0.6694 - val_y2_output_loss: 2.7212 - val_y1_output_root_mean_squared_error: 0.8292 - val_y2_output_root_mean_squared_error: 1.6628
# Epoch 95/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.9977 - y1_output_loss: 0.7390 - y2_output_loss: 2.2319 - y1_output_root_mean_squared_error: 0.8633 - y2_output_root_mean_squared_error: 1.5008 - val_loss: 2.1616 - val_y1_output_loss: 0.6603 - val_y2_output_loss: 1.4464 - val_y1_output_root_mean_squared_error: 0.8175 - val_y2_output_root_mean_squared_error: 1.2220
# Epoch 96/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.5094 - y1_output_loss: 0.6425 - y2_output_loss: 1.8855 - y1_output_root_mean_squared_error: 0.7991 - y2_output_root_mean_squared_error: 1.3678 - val_loss: 3.2653 - val_y1_output_loss: 1.2527 - val_y2_output_loss: 1.9228 - val_y1_output_root_mean_squared_error: 1.1299 - val_y2_output_root_mean_squared_error: 1.4102
# Epoch 97/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.5630 - y1_output_loss: 1.3877 - y2_output_loss: 3.1842 - y1_output_root_mean_squared_error: 1.1779 - y2_output_root_mean_squared_error: 1.7820 - val_loss: 9.3650 - val_y1_output_loss: 2.9006 - val_y2_output_loss: 6.1955 - val_y1_output_root_mean_squared_error: 1.7282 - val_y2_output_root_mean_squared_error: 2.5255
# Epoch 98/500
# 614/614 [==============================] - 0s 155us/sample - loss: 5.9079 - y1_output_loss: 2.0350 - y2_output_loss: 3.8233 - y1_output_root_mean_squared_error: 1.4329 - y2_output_root_mean_squared_error: 1.9634 - val_loss: 2.6917 - val_y1_output_loss: 0.7398 - val_y2_output_loss: 1.8799 - val_y1_output_root_mean_squared_error: 0.8709 - val_y2_output_root_mean_squared_error: 1.3904
# Epoch 99/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.3007 - y1_output_loss: 0.6000 - y2_output_loss: 1.6928 - y1_output_root_mean_squared_error: 0.7762 - y2_output_root_mean_squared_error: 1.3032 - val_loss: 2.7363 - val_y1_output_loss: 0.6378 - val_y2_output_loss: 2.0274 - val_y1_output_root_mean_squared_error: 0.8083 - val_y2_output_root_mean_squared_error: 1.4432
# Epoch 100/500
# 614/614 [==============================] - 0s 160us/sample - loss: 2.4637 - y1_output_loss: 0.6544 - y2_output_loss: 1.8085 - y1_output_root_mean_squared_error: 0.8111 - y2_output_root_mean_squared_error: 1.3438 - val_loss: 2.4754 - val_y1_output_loss: 0.6514 - val_y2_output_loss: 1.7677 - val_y1_output_root_mean_squared_error: 0.8185 - val_y2_output_root_mean_squared_error: 1.3437
# Epoch 101/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.4956 - y1_output_loss: 0.9021 - y2_output_loss: 2.5950 - y1_output_root_mean_squared_error: 0.9514 - y2_output_root_mean_squared_error: 1.6095 - val_loss: 2.9662 - val_y1_output_loss: 0.9811 - val_y2_output_loss: 1.8910 - val_y1_output_root_mean_squared_error: 1.0067 - val_y2_output_root_mean_squared_error: 1.3974
# Epoch 102/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.2885 - y1_output_loss: 0.6014 - y2_output_loss: 1.6886 - y1_output_root_mean_squared_error: 0.7764 - y2_output_root_mean_squared_error: 1.2984 - val_loss: 2.9373 - val_y1_output_loss: 0.6043 - val_y2_output_loss: 2.2581 - val_y1_output_root_mean_squared_error: 0.7854 - val_y2_output_root_mean_squared_error: 1.5233
# Epoch 103/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.8186 - y1_output_loss: 0.6953 - y2_output_loss: 2.0987 - y1_output_root_mean_squared_error: 0.8368 - y2_output_root_mean_squared_error: 1.4554 - val_loss: 1.8933 - val_y1_output_loss: 0.5542 - val_y2_output_loss: 1.2853 - val_y1_output_root_mean_squared_error: 0.7532 - val_y2_output_root_mean_squared_error: 1.1515
# Epoch 104/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.0381 - y1_output_loss: 0.7310 - y2_output_loss: 2.3084 - y1_output_root_mean_squared_error: 0.8580 - y2_output_root_mean_squared_error: 1.5172 - val_loss: 5.7284 - val_y1_output_loss: 0.9430 - val_y2_output_loss: 4.6380 - val_y1_output_root_mean_squared_error: 0.9860 - val_y2_output_root_mean_squared_error: 2.1809
# Epoch 105/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.8542 - y1_output_loss: 1.3060 - y2_output_loss: 3.5436 - y1_output_root_mean_squared_error: 1.1468 - y2_output_root_mean_squared_error: 1.8812 - val_loss: 5.3292 - val_y1_output_loss: 0.9113 - val_y2_output_loss: 4.3159 - val_y1_output_root_mean_squared_error: 0.9648 - val_y2_output_root_mean_squared_error: 2.0972
# Epoch 106/500
# 614/614 [==============================] - 0s 180us/sample - loss: 2.6167 - y1_output_loss: 0.6545 - y2_output_loss: 1.9418 - y1_output_root_mean_squared_error: 0.8126 - y2_output_root_mean_squared_error: 1.3987 - val_loss: 1.8614 - val_y1_output_loss: 0.5380 - val_y2_output_loss: 1.2800 - val_y1_output_root_mean_squared_error: 0.7376 - val_y2_output_root_mean_squared_error: 1.1477
# Epoch 107/500
# 614/614 [==============================] - 0s 160us/sample - loss: 1.8122 - y1_output_loss: 0.4568 - y2_output_loss: 1.3861 - y1_output_root_mean_squared_error: 0.6771 - y2_output_root_mean_squared_error: 1.1635 - val_loss: 6.1149 - val_y1_output_loss: 1.1527 - val_y2_output_loss: 4.8445 - val_y1_output_root_mean_squared_error: 1.0811 - val_y2_output_root_mean_squared_error: 2.2240
# Epoch 108/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.1195 - y1_output_loss: 0.7975 - y2_output_loss: 2.3308 - y1_output_root_mean_squared_error: 0.8954 - y2_output_root_mean_squared_error: 1.5224 - val_loss: 3.0293 - val_y1_output_loss: 0.8350 - val_y2_output_loss: 2.1264 - val_y1_output_root_mean_squared_error: 0.9250 - val_y2_output_root_mean_squared_error: 1.4744
# Epoch 109/500
# 614/614 [==============================] - 0s 162us/sample - loss: 3.8933 - y1_output_loss: 1.0646 - y2_output_loss: 2.7968 - y1_output_root_mean_squared_error: 1.0365 - y2_output_root_mean_squared_error: 1.6790 - val_loss: 1.8743 - val_y1_output_loss: 0.4994 - val_y2_output_loss: 1.3209 - val_y1_output_root_mean_squared_error: 0.7122 - val_y2_output_root_mean_squared_error: 1.1692
# Epoch 110/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.1257 - y1_output_loss: 0.8705 - y2_output_loss: 2.2313 - y1_output_root_mean_squared_error: 0.9343 - y2_output_root_mean_squared_error: 1.5009 - val_loss: 1.8108 - val_y1_output_loss: 0.4732 - val_y2_output_loss: 1.2875 - val_y1_output_root_mean_squared_error: 0.6945 - val_y2_output_root_mean_squared_error: 1.1526
# Epoch 111/500
# 614/614 [==============================] - 0s 163us/sample - loss: 2.1179 - y1_output_loss: 0.4997 - y2_output_loss: 1.6063 - y1_output_root_mean_squared_error: 0.7095 - y2_output_root_mean_squared_error: 1.2706 - val_loss: 2.1352 - val_y1_output_loss: 0.6622 - val_y2_output_loss: 1.4090 - val_y1_output_root_mean_squared_error: 0.8259 - val_y2_output_root_mean_squared_error: 1.2054
# Epoch 112/500
# 614/614 [==============================] - 0s 164us/sample - loss: 2.8610 - y1_output_loss: 0.6872 - y2_output_loss: 2.2837 - y1_output_root_mean_squared_error: 0.8085 - y2_output_root_mean_squared_error: 1.4857 - val_loss: 14.9552 - val_y1_output_loss: 5.6731 - val_y2_output_loss: 9.3150 - val_y1_output_root_mean_squared_error: 2.3701 - val_y2_output_root_mean_squared_error: 3.0558
# Epoch 113/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.5949 - y1_output_loss: 0.9028 - y2_output_loss: 2.6841 - y1_output_root_mean_squared_error: 0.9523 - y2_output_root_mean_squared_error: 1.6395 - val_loss: 2.7434 - val_y1_output_loss: 0.7179 - val_y2_output_loss: 2.0079 - val_y1_output_root_mean_squared_error: 0.8477 - val_y2_output_root_mean_squared_error: 1.4229
# Epoch 114/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.5135 - y1_output_loss: 0.8444 - y2_output_loss: 2.6487 - y1_output_root_mean_squared_error: 0.9222 - y2_output_root_mean_squared_error: 1.6319 - val_loss: 4.3706 - val_y1_output_loss: 1.2900 - val_y2_output_loss: 2.9491 - val_y1_output_root_mean_squared_error: 1.1487 - val_y2_output_root_mean_squared_error: 1.7467
# Epoch 115/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.0075 - y1_output_loss: 0.4930 - y2_output_loss: 1.5212 - y1_output_root_mean_squared_error: 0.7037 - y2_output_root_mean_squared_error: 1.2298 - val_loss: 1.8565 - val_y1_output_loss: 0.5795 - val_y2_output_loss: 1.2192 - val_y1_output_root_mean_squared_error: 0.7738 - val_y2_output_root_mean_squared_error: 1.1215
# Epoch 116/500
# 614/614 [==============================] - 0s 142us/sample - loss: 7.2405 - y1_output_loss: 2.0130 - y2_output_loss: 5.1700 - y1_output_root_mean_squared_error: 1.4253 - y2_output_root_mean_squared_error: 2.2823 - val_loss: 2.9219 - val_y1_output_loss: 1.0177 - val_y2_output_loss: 1.8191 - val_y1_output_root_mean_squared_error: 1.0253 - val_y2_output_root_mean_squared_error: 1.3677
# Epoch 117/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.5772 - y1_output_loss: 0.5839 - y2_output_loss: 2.0000 - y1_output_root_mean_squared_error: 0.7668 - y2_output_root_mean_squared_error: 1.4104 - val_loss: 4.1215 - val_y1_output_loss: 0.6451 - val_y2_output_loss: 3.4100 - val_y1_output_root_mean_squared_error: 0.8026 - val_y2_output_root_mean_squared_error: 1.8648
# Epoch 118/500
# 614/614 [==============================] - 0s 151us/sample - loss: 2.1765 - y1_output_loss: 0.5109 - y2_output_loss: 1.6520 - y1_output_root_mean_squared_error: 0.7171 - y2_output_root_mean_squared_error: 1.2893 - val_loss: 2.0373 - val_y1_output_loss: 0.4073 - val_y2_output_loss: 1.5776 - val_y1_output_root_mean_squared_error: 0.6441 - val_y2_output_root_mean_squared_error: 1.2738
# Epoch 119/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.7057 - y1_output_loss: 0.8516 - y2_output_loss: 2.9043 - y1_output_root_mean_squared_error: 0.9244 - y2_output_root_mean_squared_error: 1.6885 - val_loss: 25.9629 - val_y1_output_loss: 9.5020 - val_y2_output_loss: 15.6110 - val_y1_output_root_mean_squared_error: 3.1350 - val_y2_output_root_mean_squared_error: 4.0168
# Epoch 120/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.6399 - y1_output_loss: 0.8226 - y2_output_loss: 1.8141 - y1_output_root_mean_squared_error: 0.9076 - y2_output_root_mean_squared_error: 1.3477 - val_loss: 1.8315 - val_y1_output_loss: 0.5224 - val_y2_output_loss: 1.2659 - val_y1_output_root_mean_squared_error: 0.7258 - val_y2_output_root_mean_squared_error: 1.1422
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.3215 - y1_output_loss: 0.1138 - y2_output_loss: 0.2097 - y1_output_root_mean_squared_error: 0.3331 - y2_output_root_mean_squared_error: 0.4588 - val_loss: 0.7275 - val_y1_output_loss: 0.2467 - val_y2_output_loss: 0.4806 - val_y1_output_root_mean_squared_error: 0.4960 - val_y2_output_root_mean_squared_error: 0.6938
# Epoch 462/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4010 - y1_output_loss: 0.1091 - y2_output_loss: 0.2895 - y1_output_root_mean_squared_error: 0.3308 - y2_output_root_mean_squared_error: 0.5400 - val_loss: 0.6238 - val_y1_output_loss: 0.1894 - val_y2_output_loss: 0.4230 - val_y1_output_root_mean_squared_error: 0.4393 - val_y2_output_root_mean_squared_error: 0.6564
# Epoch 463/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.3287 - y1_output_loss: 0.1004 - y2_output_loss: 0.2262 - y1_output_root_mean_squared_error: 0.3179 - y2_output_root_mean_squared_error: 0.4772 - val_loss: 0.6084 - val_y1_output_loss: 0.2021 - val_y2_output_loss: 0.3923 - val_y1_output_root_mean_squared_error: 0.4544 - val_y2_output_root_mean_squared_error: 0.6340
# Epoch 464/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4579 - y1_output_loss: 0.1201 - y2_output_loss: 0.3364 - y1_output_root_mean_squared_error: 0.3478 - y2_output_root_mean_squared_error: 0.5804 - val_loss: 0.9191 - val_y1_output_loss: 0.3040 - val_y2_output_loss: 0.6100 - val_y1_output_root_mean_squared_error: 0.5477 - val_y2_output_root_mean_squared_error: 0.7869
# Epoch 465/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4167 - y1_output_loss: 0.1164 - y2_output_loss: 0.3018 - y1_output_root_mean_squared_error: 0.3423 - y2_output_root_mean_squared_error: 0.5473 - val_loss: 0.6525 - val_y1_output_loss: 0.1974 - val_y2_output_loss: 0.4441 - val_y1_output_root_mean_squared_error: 0.4439 - val_y2_output_root_mean_squared_error: 0.6749
# Epoch 466/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.3713 - y1_output_loss: 0.1184 - y2_output_loss: 0.2510 - y1_output_root_mean_squared_error: 0.3444 - y2_output_root_mean_squared_error: 0.5027 - val_loss: 0.6879 - val_y1_output_loss: 0.2387 - val_y2_output_loss: 0.4425 - val_y1_output_root_mean_squared_error: 0.4910 - val_y2_output_root_mean_squared_error: 0.6684
# Epoch 467/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.3381 - y1_output_loss: 0.1058 - y2_output_loss: 0.2321 - y1_output_root_mean_squared_error: 0.3247 - y2_output_root_mean_squared_error: 0.4824 - val_loss: 0.8457 - val_y1_output_loss: 0.2038 - val_y2_output_loss: 0.6299 - val_y1_output_root_mean_squared_error: 0.4517 - val_y2_output_root_mean_squared_error: 0.8010
# Epoch 468/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.3385 - y1_output_loss: 0.1115 - y2_output_loss: 0.2429 - y1_output_root_mean_squared_error: 0.3274 - y2_output_root_mean_squared_error: 0.4809 - val_loss: 3.0134 - val_y1_output_loss: 0.4665 - val_y2_output_loss: 2.5517 - val_y1_output_root_mean_squared_error: 0.6901 - val_y2_output_root_mean_squared_error: 1.5928
# Epoch 469/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.4672 - y1_output_loss: 0.1246 - y2_output_loss: 0.3413 - y1_output_root_mean_squared_error: 0.3529 - y2_output_root_mean_squared_error: 0.5854 - val_loss: 0.7527 - val_y1_output_loss: 0.2197 - val_y2_output_loss: 0.5266 - val_y1_output_root_mean_squared_error: 0.4712 - val_y2_output_root_mean_squared_error: 0.7285
# Epoch 470/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.3619 - y1_output_loss: 0.1023 - y2_output_loss: 0.2570 - y1_output_root_mean_squared_error: 0.3205 - y2_output_root_mean_squared_error: 0.5091 - val_loss: 0.5947 - val_y1_output_loss: 0.1939 - val_y2_output_loss: 0.3932 - val_y1_output_root_mean_squared_error: 0.4387 - val_y2_output_root_mean_squared_error: 0.6342
# Epoch 471/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.3528 - y1_output_loss: 0.1089 - y2_output_loss: 0.2436 - y1_output_root_mean_squared_error: 0.3284 - y2_output_root_mean_squared_error: 0.4950 - val_loss: 0.7736 - val_y1_output_loss: 0.2373 - val_y2_output_loss: 0.5330 - val_y1_output_root_mean_squared_error: 0.4838 - val_y2_output_root_mean_squared_error: 0.7345
# Epoch 472/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.3765 - y1_output_loss: 0.1172 - y2_output_loss: 0.2707 - y1_output_root_mean_squared_error: 0.3415 - y2_output_root_mean_squared_error: 0.5097 - val_loss: 2.1841 - val_y1_output_loss: 0.4827 - val_y2_output_loss: 1.6920 - val_y1_output_root_mean_squared_error: 0.6901 - val_y2_output_root_mean_squared_error: 1.3069
# Epoch 473/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4204 - y1_output_loss: 0.1182 - y2_output_loss: 0.3015 - y1_output_root_mean_squared_error: 0.3429 - y2_output_root_mean_squared_error: 0.5502 - val_loss: 0.6563 - val_y1_output_loss: 0.1853 - val_y2_output_loss: 0.4617 - val_y1_output_root_mean_squared_error: 0.4327 - val_y2_output_root_mean_squared_error: 0.6849
# Epoch 474/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.2786 - y1_output_loss: 0.0899 - y2_output_loss: 0.1880 - y1_output_root_mean_squared_error: 0.3005 - y2_output_root_mean_squared_error: 0.4339 - val_loss: 0.6537 - val_y1_output_loss: 0.2075 - val_y2_output_loss: 0.4425 - val_y1_output_root_mean_squared_error: 0.4542 - val_y2_output_root_mean_squared_error: 0.6689
# Epoch 475/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4994 - y1_output_loss: 0.1422 - y2_output_loss: 0.3530 - y1_output_root_mean_squared_error: 0.3783 - y2_output_root_mean_squared_error: 0.5969 - val_loss: 0.9014 - val_y1_output_loss: 0.2511 - val_y2_output_loss: 0.6376 - val_y1_output_root_mean_squared_error: 0.5007 - val_y2_output_root_mean_squared_error: 0.8066
# Epoch 476/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4667 - y1_output_loss: 0.0992 - y2_output_loss: 0.3638 - y1_output_root_mean_squared_error: 0.3163 - y2_output_root_mean_squared_error: 0.6056 - val_loss: 0.6186 - val_y1_output_loss: 0.2189 - val_y2_output_loss: 0.3923 - val_y1_output_root_mean_squared_error: 0.4682 - val_y2_output_root_mean_squared_error: 0.6320
# Epoch 477/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.3422 - y1_output_loss: 0.1102 - y2_output_loss: 0.2309 - y1_output_root_mean_squared_error: 0.3317 - y2_output_root_mean_squared_error: 0.4819 - val_loss: 0.5776 - val_y1_output_loss: 0.1847 - val_y2_output_loss: 0.3884 - val_y1_output_root_mean_squared_error: 0.4285 - val_y2_output_root_mean_squared_error: 0.6277
# Epoch 478/500
# 614/614 [==============================] - 0s 173us/sample - loss: 0.4282 - y1_output_loss: 0.1239 - y2_output_loss: 0.3014 - y1_output_root_mean_squared_error: 0.3529 - y2_output_root_mean_squared_error: 0.5511 - val_loss: 0.6081 - val_y1_output_loss: 0.2009 - val_y2_output_loss: 0.4039 - val_y1_output_root_mean_squared_error: 0.4478 - val_y2_output_root_mean_squared_error: 0.6384
# Epoch 479/500
# 614/614 [==============================] - 0s 164us/sample - loss: 0.5204 - y1_output_loss: 0.1315 - y2_output_loss: 0.3914 - y1_output_root_mean_squared_error: 0.3633 - y2_output_root_mean_squared_error: 0.6232 - val_loss: 1.1643 - val_y1_output_loss: 0.1954 - val_y2_output_loss: 0.9477 - val_y1_output_root_mean_squared_error: 0.4429 - val_y2_output_root_mean_squared_error: 0.9839
# Epoch 480/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.5043 - y1_output_loss: 0.1364 - y2_output_loss: 0.3668 - y1_output_root_mean_squared_error: 0.3704 - y2_output_root_mean_squared_error: 0.6058 - val_loss: 0.5710 - val_y1_output_loss: 0.1829 - val_y2_output_loss: 0.3788 - val_y1_output_root_mean_squared_error: 0.4282 - val_y2_output_root_mean_squared_error: 0.6226
# Epoch 481/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3629 - y1_output_loss: 0.1096 - y2_output_loss: 0.2518 - y1_output_root_mean_squared_error: 0.3304 - y2_output_root_mean_squared_error: 0.5037 - val_loss: 0.6734 - val_y1_output_loss: 0.2062 - val_y2_output_loss: 0.4673 - val_y1_output_root_mean_squared_error: 0.4523 - val_y2_output_root_mean_squared_error: 0.6847
# Epoch 482/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4347 - y1_output_loss: 0.1270 - y2_output_loss: 0.3421 - y1_output_root_mean_squared_error: 0.3516 - y2_output_root_mean_squared_error: 0.5577 - val_loss: 7.1466 - val_y1_output_loss: 1.1120 - val_y2_output_loss: 5.8781 - val_y1_output_root_mean_squared_error: 1.0612 - val_y2_output_root_mean_squared_error: 2.4537
# Epoch 483/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.7179 - y1_output_loss: 0.1852 - y2_output_loss: 0.5286 - y1_output_root_mean_squared_error: 0.4318 - y2_output_root_mean_squared_error: 0.7291 - val_loss: 0.6901 - val_y1_output_loss: 0.2232 - val_y2_output_loss: 0.4508 - val_y1_output_root_mean_squared_error: 0.4754 - val_y2_output_root_mean_squared_error: 0.6812
# Epoch 484/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.3616 - y1_output_loss: 0.1102 - y2_output_loss: 0.2487 - y1_output_root_mean_squared_error: 0.3330 - y2_output_root_mean_squared_error: 0.5007 - val_loss: 0.5908 - val_y1_output_loss: 0.1994 - val_y2_output_loss: 0.3888 - val_y1_output_root_mean_squared_error: 0.4458 - val_y2_output_root_mean_squared_error: 0.6261
# Epoch 485/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3731 - y1_output_loss: 0.1148 - y2_output_loss: 0.2634 - y1_output_root_mean_squared_error: 0.3376 - y2_output_root_mean_squared_error: 0.5091 - val_loss: 1.2703 - val_y1_output_loss: 0.3894 - val_y2_output_loss: 0.8690 - val_y1_output_root_mean_squared_error: 0.6258 - val_y2_output_root_mean_squared_error: 0.9374
# Epoch 486/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3789 - y1_output_loss: 0.1081 - y2_output_loss: 0.2844 - y1_output_root_mean_squared_error: 0.3290 - y2_output_root_mean_squared_error: 0.5203 - val_loss: 3.8562 - val_y1_output_loss: 0.4440 - val_y2_output_loss: 3.3319 - val_y1_output_root_mean_squared_error: 0.6746 - val_y2_output_root_mean_squared_error: 1.8442
# Epoch 487/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4295 - y1_output_loss: 0.1262 - y2_output_loss: 0.3010 - y1_output_root_mean_squared_error: 0.3566 - y2_output_root_mean_squared_error: 0.5499 - val_loss: 0.8275 - val_y1_output_loss: 0.2154 - val_y2_output_loss: 0.5989 - val_y1_output_root_mean_squared_error: 0.4661 - val_y2_output_root_mean_squared_error: 0.7812
# Epoch 488/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.4990 - y1_output_loss: 0.1334 - y2_output_loss: 0.3647 - y1_output_root_mean_squared_error: 0.3634 - y2_output_root_mean_squared_error: 0.6058 - val_loss: 1.2993 - val_y1_output_loss: 0.3815 - val_y2_output_loss: 0.8840 - val_y1_output_root_mean_squared_error: 0.6263 - val_y2_output_root_mean_squared_error: 0.9524
# Epoch 489/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.3969 - y1_output_loss: 0.1174 - y2_output_loss: 0.2773 - y1_output_root_mean_squared_error: 0.3436 - y2_output_root_mean_squared_error: 0.5281 - val_loss: 0.7372 - val_y1_output_loss: 0.2343 - val_y2_output_loss: 0.4928 - val_y1_output_root_mean_squared_error: 0.4831 - val_y2_output_root_mean_squared_error: 0.7098
# Epoch 490/500
# 614/614 [==============================] - 0s 168us/sample - loss: 0.3004 - y1_output_loss: 0.0971 - y2_output_loss: 0.2035 - y1_output_root_mean_squared_error: 0.3119 - y2_output_root_mean_squared_error: 0.4507 - val_loss: 0.9811 - val_y1_output_loss: 0.2423 - val_y2_output_loss: 0.7291 - val_y1_output_root_mean_squared_error: 0.4897 - val_y2_output_root_mean_squared_error: 0.8610
# Epoch 491/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.4761 - y1_output_loss: 0.1199 - y2_output_loss: 0.3529 - y1_output_root_mean_squared_error: 0.3468 - y2_output_root_mean_squared_error: 0.5965 - val_loss: 0.6375 - val_y1_output_loss: 0.1998 - val_y2_output_loss: 0.4329 - val_y1_output_root_mean_squared_error: 0.4455 - val_y2_output_root_mean_squared_error: 0.6625
# Epoch 492/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.7160 - y1_output_loss: 0.1756 - y2_output_loss: 0.5583 - y1_output_root_mean_squared_error: 0.4154 - y2_output_root_mean_squared_error: 0.7372 - val_loss: 3.8135 - val_y1_output_loss: 1.0081 - val_y2_output_loss: 2.7021 - val_y1_output_root_mean_squared_error: 1.0163 - val_y2_output_root_mean_squared_error: 1.6675
# Epoch 493/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.5669 - y1_output_loss: 0.1698 - y2_output_loss: 0.3930 - y1_output_root_mean_squared_error: 0.4139 - y2_output_root_mean_squared_error: 0.6290 - val_loss: 0.6893 - val_y1_output_loss: 0.1985 - val_y2_output_loss: 0.4748 - val_y1_output_root_mean_squared_error: 0.4491 - val_y2_output_root_mean_squared_error: 0.6983
# Epoch 494/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3752 - y1_output_loss: 0.1057 - y2_output_loss: 0.2731 - y1_output_root_mean_squared_error: 0.3264 - y2_output_root_mean_squared_error: 0.5184 - val_loss: 1.2678 - val_y1_output_loss: 0.2142 - val_y2_output_loss: 1.0359 - val_y1_output_root_mean_squared_error: 0.4646 - val_y2_output_root_mean_squared_error: 1.0257
# Epoch 495/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.4287 - y1_output_loss: 0.1163 - y2_output_loss: 0.3097 - y1_output_root_mean_squared_error: 0.3416 - y2_output_root_mean_squared_error: 0.5586 - val_loss: 0.7075 - val_y1_output_loss: 0.2352 - val_y2_output_loss: 0.4629 - val_y1_output_root_mean_squared_error: 0.4875 - val_y2_output_root_mean_squared_error: 0.6855
# Epoch 496/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.2771 - y1_output_loss: 0.0921 - y2_output_loss: 0.1830 - y1_output_root_mean_squared_error: 0.3044 - y2_output_root_mean_squared_error: 0.4295 - val_loss: 0.7091 - val_y1_output_loss: 0.2340 - val_y2_output_loss: 0.4666 - val_y1_output_root_mean_squared_error: 0.4873 - val_y2_output_root_mean_squared_error: 0.6868
# Epoch 497/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.3709 - y1_output_loss: 0.1201 - y2_output_loss: 0.2602 - y1_output_root_mean_squared_error: 0.3456 - y2_output_root_mean_squared_error: 0.5015 - val_loss: 0.8396 - val_y1_output_loss: 0.2557 - val_y2_output_loss: 0.5795 - val_y1_output_root_mean_squared_error: 0.5045 - val_y2_output_root_mean_squared_error: 0.7649
# Epoch 498/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.3095 - y1_output_loss: 0.0953 - y2_output_loss: 0.2126 - y1_output_root_mean_squared_error: 0.3100 - y2_output_root_mean_squared_error: 0.4619 - val_loss: 0.6258 - val_y1_output_loss: 0.2074 - val_y2_output_loss: 0.4147 - val_y1_output_root_mean_squared_error: 0.4517 - val_y2_output_root_mean_squared_error: 0.6494
# Epoch 499/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3542 - y1_output_loss: 0.0978 - y2_output_loss: 0.2617 - y1_output_root_mean_squared_error: 0.3055 - y2_output_root_mean_squared_error: 0.5108 - val_loss: 0.8816 - val_y1_output_loss: 0.4122 - val_y2_output_loss: 0.4506 - val_y1_output_root_mean_squared_error: 0.6470 - val_y2_output_root_mean_squared_error: 0.6804
# Epoch 500/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.2919 - y1_output_loss: 0.0971 - y2_output_loss: 0.1974 - y1_output_root_mean_squared_error: 0.3123 - y2_output_root_mean_squared_error: 0.4409 - val_loss: 0.5878 - val_y1_output_loss: 0.1894 - val_y2_output_loss: 0.3900 - val_y1_output_root_mean_squared_error: 0.4344 - val_y2_output_root_mean_squared_error: 0.6317

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 52us/sample - loss: 0.5878 - y1_output_loss: 0.1852 - y2_output_loss: 0.3946 - y1_output_root_mean_squared_error: 0.4344 - y2_output_root_mean_squared_error: 0.6317
# Loss = 0.5878179522303791, Y1_loss = 0.18521112203598022, Y1_mse = 0.4344259202480316, Y2_loss = 0.3946371376514435, Y2_mse = 0.6317373514175415

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
